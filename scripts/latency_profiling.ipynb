# %%
import requests 
SERVER = 'http://127.0.0.1:5000/'

# %timeit r = requests.get(SERVER + '/api/query', json={'query': 'christmas dress'}, headers={'Content-Type': 'application/json'})
# Out:
# 31.6 ms ± 890 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
r = requests.get(SERVER + '/api/query', json={'query': 'christmas dress'}, headers={'Content-Type': 'application/json'})
print(r.json())
# Out:
# {'indices': [264800, 159510, 203093, 189124, 245646, 166596, 145821, 30054, 87929, 86373, 142017, 178883, 176704, 114493, 141421, 180295, 227893, 89552, 292677, 133610, 49776, 237827, 77981, 94032, 235373, 81151, 63377, 66162, 183441, 96097, 270459, 116585, 283528, 241845, 36329, 181493, 160396, 292860, 183036, 134526, 8844, 129359, 266347, 208006, 181356, 242785, 220576, 40391, 205233, 297412, 7435, 186699, 152036, 144956, 50569, 4778, 302833, 236505, 73143, 68036, 213188, 57349, 90729, 32200, 96774, 123559, 281202, 269953, 19402, 235322, 290998, 306278, 17088, 249295, 124482, 126102, 122029, 86332, 159561, 249820, 142762, 58549, 6943, 3377, 59602, 204745, 282089, 29664, 149739, 236105, 28508, 156525, 2934, 290751, 36373, 36706, 266145, 248817, 27914, 111621], 'query': 'christmas dress', 'scores': [0.316325843334198, 0.3077372908592224, 0.3015078604221344, 0.29790985584259033, 0.29668477177619934, 0.2958116829395294, 0.29578179121017456, 0.29256463050842285, 0.29249313473701477, 0.2
# ...
